# %% [markdown]
# <a href="https://colab.research.google.com/github/benjackson3811/Destructuring/blob/main/40_data_science_projects_with_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 40 data science projects with datasets
#
# https://medium.com/data-science-collective/40-data-science-projects-with-datasets-you-should-try-9d9f89ab5dc2
